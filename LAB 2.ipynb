# %%
class Student:
    def __init__(self,name, roll_no,program):
        self.name = name
        self.roll_no = roll_no
        self.program = program

    def display_info(self):
        print(f"Name: {self.name}, Roll_no: {self.roll_no}, Program: {self.program}")

s1 = Student("Hamid","24k-001","BSCS")
s2 = Student("Hammad","24k-0544","BSCS")

s1.display_info()
s2.display_info()
# Out:
# Name: Hamid, Roll_no: 24k-001, Program: BSCS
# Name: Hammad, Roll_no: 24k-0544, Program: BSCS

# %%
class SmartFan:
    def __init__(self, room_name):
        self.room_name = room_name
        self.speed = 0
    def increase_speed(self,x):
        self.speed += x
    def decrease_speed(self,x):
        self.speed -= x
    def display_status(self):
        print(f"Room Name: {self.room_name}, Speed: {self.speed}")

f1 = SmartFan("Room1")
f2 = SmartFan("Room2")
print("Before Increase:")
f1.increase_speed(5)
f1.display_status()
print("Before Decrease:")
f1.decrease_speed(2)
f1.display_status()
print("Before Increase:")
f2.increase_speed(10)
f2.display_status()
print("Before Decrease:")
f2.decrease_speed(6)
f2.display_status()
# Out:
# Before Increase:
# Room Name: Room1, Speed: 5
# Before Decrease:
# Room Name: Room1, Speed: 3
# Before Increase:
# Room Name: Room2, Speed: 10
# Before Decrease:
# Room Name: Room2, Speed: 4

# %%
class Book:
    library_name = "FAST Library"
    def __init__(self, title, author):
        self.title = title
        self.author = author
    def display_book(self):
        print(f"Library: {Book.library_name}, Title: {self.title}, Author: {self.author}")

b1 = Book("Harry Potter","JK Rowling")
b2 = Book("Calculus","Anton")
b1.display_book()
b2.display_book()
Book.library_name = "NUST Library"
print("After changing class attribute(Library name)")
b1.display_book()
b2.display_book()
# Out:
# Library: FAST Library, Title: Harry Potter, Author: JK Rowling
# Library: FAST Library, Title: Calculus, Author: Anton
# After changing class attribute(Library name)
# Library: NUST Library, Title: Harry Potter, Author: JK Rowling
# Library: NUST Library, Title: Calculus, Author: Anton

# %%
class BankAccount:
    def __init__(self,account_holder, account_no, balance):
        self.account_holder = account_holder
        self.account_no = account_no
        self.balance = balance

    def deposit(self,amount):
        self.balance += amount
        print(f"Amount: {amount} successfully deposited!")

    def withdraw(self,amount):
        if(self.balance >= amount):
            self.balance -= amount
        else:
            print("Insufficient Balance")
    def display_account(self):
        print(f"Account Holder: {self.account_holder}, Account number: {self.account_no}, Balance: {self.balance}")


b1 = BankAccount("Immad",76867345,1500)
b2 = BankAccount("Huzaifa",610037596, 2010)
b1.display_account()
b2.display_account()
print("-------------Depsoiting 1000 in b1 & b2-------------")
b1.deposit(1000)
b1.display_account()
b2.deposit(1000)
b2.display_account()
print("-----------Withdraw 2000 from b1 & b2----------")
b1.withdraw(2000)
b2.withdraw(2000)
b1.display_account()
b2.display_account()
# Out:
# Account Holder: Immad, Account number: 76867345, Balance: 1500
# Account Holder: Huzaifa, Account number: 610037596, Balance: 2010
# -------------Depsoiting 1000 in b1 & b2-------------
# Amount: 1000 successfully deposited!
# Account Holder: Immad, Account number: 76867345, Balance: 2500
# Amount: 1000 successfully deposited!
# Account Holder: Huzaifa, Account number: 610037596, Balance: 3010
# -----------Withdraw 2000 from b1 & b2----------
# Account Holder: Immad, Account number: 76867345, Balance: 500
# Account Holder: Huzaifa, Account number: 610037596, Balance: 1010

# %%
class SmartLight:
    def __init__(self,room):
        self.room = room
        self.status = 0
    def turn_on(self):
        self.status = 1
    def turn_off(self):
        self.status = 0
    def showstatus(self):
        print(f"Room: {self.room}")
        if(self.status == 1):
            print("Status:ON")
        else:
            print("Status:OFF")
r1 = SmartLight("Lounge")
r2 = SmartLight("Bedroom")
r1.showstatus()
r2.showstatus()
print("Turning the light on....")
r1.turn_on()
r2.turn_on()
r1.showstatus()
r2.showstatus()
# Out:
# Room: Lounge
# Status:OFF
# Room: Bedroom
# Status:OFF
# Turning the light on....
# Room: Lounge
# Status:ON
# Room: Bedroom
# Status:ON

# %%
class Staff:
    def __init__(self, name, staff_id, department):
        self.name = name
        self.staff_id = staff_id
        self.department = department

    def display_info(self):
        print(f"Name: {self.name}, Staff ID: {self.staff_id}, Department: {self.department}")
        
class Teacher(Staff):
    def __init__(self, name, staff_id, department, courses, salary):
        self.name = name
        self.staff_id = staff_id
        self.department = department
        self.courses = courses
        self.salary = salary

    def display_info(self):
        super().display_info()
        print(f"Courses: {self.courses}, Salary: {self.salary}")
        
class AdminStaff(Staff):
    def __init__(self, name, staff_id, department, role, working_hours):
        self.name = name
        self.staff_id = staff_id
        self.department = department
        self.role = role
        self.working_hours = working_hours

    def display_info(self):
        super().display_info()
        print(f"Role: {self.role}, Working hours: {self.working_hours}")

class ResearchAssistant(Staff):
    def __init__(self,name, staff_id, department, research_topic, stipend):
        self.name = name
        self.staff_id = staff_id
        self.department = department
        self.research_topic = research_topic
        self.stipend = stipend

    def display_info(self):
        super().display_info()
        print(f"Research Topic: {self.research_topic}, Stipend: {self.stipend}")

t1 = Teacher("Ahmed","204895k","AI","NLP",75000)
as1 = AdminStaff("Ali","658747k","CYS","Assit Lecturer",9)
rs1 = ResearchAssistant("Aliyaan","24k0855","CS","Computer Network",10000)

print("-----Teacher-----")
t1.display_info()
print("-----AdminStaff-----")
as1.display_info()
print("-----ResearchAssistant-----")
rs1.display_info()
# Out:
# -----Teacher-----
# Name: Ahmed, Staff ID: 204895k, Department: AI
# Courses: NLP, Salary: 75000
# -----AdminStaff-----
# Name: Ali, Staff ID: 658747k, Department: CYS
# Role: Assit Lecturer, Working hours: 9
# -----ResearchAssistant-----
# Name: Aliyaan, Staff ID: 24k0855, Department: CS
# Research Topic: Computer Network, Stipend: 10000

# %%
class Vehicle:
    def start(self):
        print("The Vehicle is starting...")

class car(Vehicle):
    def start(self):
        print("The Car is starting...")

class bike(Vehicle):
    def start(self):
        print("The Bike is starting...")

class bus(Vehicle):
    def start(self):
        print("The Bus is starting...")

c1 = car()
bike1 = bike()
bus1 = bus()

c1.start()
bike1.start()
bus1.start()
# Out:
# The Car is starting...
# The Bike is starting...
# The Bus is starting...

# %%
class Calculator:
    def multiply(self, a, b=1):
        return a * b
    def multiply(self, *args):
        mul = 1
        for i in args:
            mul *= i
        return mul
calc = Calculator()
print("Method Overloading default arg Examples:")
print(calc.multiply(5, 10))
print(calc.multiply(7))
print("Method Overloading *args Examples:")
print(calc.multiply(5, 10))
print(calc.multiply(5, 10, 15))
print(calc.multiply(1, 2, 3, 4))
# Out:
# Method Overloading default arg Examples:
# 50
# 7
# Method Overloading *args Examples:
# 50
# 750
# 24

# %%
class Employee:
    def __init__(self, name, salary):
        self._name = name
        self._salary = salary

    def display(self):
        print(f"Name: {self._name}, Salary: ${self._salary}")

class Manager(Employee):
    def display(self):
        super().display()

m1 = Manager("Emma",55000)
m1.display()
# Out:
# Name: Emma, Salary: $55000

# %%
class BankAccount:
    def __init__(self, balance):
        self.__balance = balance
        
    def deposit(self,amount):
        self.__balance += amount
        print(f"Amount deposit successful: {amount}")
        
    def withdraw(self,amount):
        if(self.__balance >= amount):
            self.__balance -= amount
            print(f"Amount withdraw successful: {amount}")
        else:
            print("Insufficient Balance")
            
    def get_balance(self):
        print(f"Balance: {self.__balance}")

b1 = BankAccount(1500)
b1.get_balance()
b1.deposit(1000)
b1.withdraw(500)
b1.get_balance()

acc = BankAccount(5000)
acc.get_balance() 
acc.__balance = 5000000 
print("Cannot access __balance directly from outside!")
acc.get_balance()
# Out:
# Balance: 1500
# Amount deposit successful: 1000
# Amount withdraw successful: 500
# Balance: 2000
# Balance: 5000
# Cannot access __balance directly from outside!
# Balance: 5000
